# %%
import pandas as pd
import numpy as np

# %%
cw = pd.read_csv(r'C:\Users\Joy\Downloads\CW1_resit_dataset.csv (1)\CW1_resit_dataset.csv')
cw.head()
# Out:
#    instant      dteday  season  hr weekday  weathersit  temp   atemp   hum  \
# 0        1  2011-01-01     1.0   0  Monday           1  0.24  0.2879  0.81
# 1        2  2011-01-01     NaN   1  Monday           1  0.22  0.2727  0.80
# 2        3  2011-01-01     1.0   2  Monday           1  0.22  0.2727  0.80
# 3        4  2011-01-01     1.0   3  Monday           1  0.24  0.2879  0.75
# 4        5  2011-01-01     1.0   4  Monday           1  0.24  0.2879  0.75
#
#    windspeed  casual  registered
# 0        0.0       3          13
# 1        0.0       8          32
# 2        0.0       5          27
# 3        0.0       3          10
# 4        0.0       0           1

# %%
cw.dtypes #data types
# Out:
# instant         int64
# dteday         object
# season        float64
# hr              int64
# weekday        object
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# dtype: object

# %%
categorical_cols = []
continuous_cols = []

for col in cw.columns:
    if cw[col].dtype == 'object' or cw[col].nunique() < 10:
        categorical_cols.append(col)
    else:
        continuous_cols.append(col)

print('Categorical columns:', categorical_cols) #whether they are categorical or continous
print('Continuous columns:', continuous_cols)
# Out:
# Categorical columns: ['dteday', 'season', 'weekday', 'weathersit']
# Continuous columns: ['instant', 'hr', 'temp', 'atemp', 'hum', 'windspeed', 'casual', 'registered']

# %%
cw.isnull().sum()
# Out:
# instant          0
# dteday           0
# season        2596
# hr               0
# weekday          0
# weathersit       0
# temp             0
# atemp            0
# hum           1742
# windspeed        0
# casual           0
# registered       0
# dtype: int64

# %%
cw['season'].fillna(method='ffill')
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 17374    1.0
# 17375    1.0
# 17376    1.0
# 17377    1.0
# 17378    1.0
# Name: season, Length: 17379, dtype: float64

# %%
cw['hum']
# Out:
# 0        0.81
# 1        0.80
# 2        0.80
# 3        0.75
# 4        0.75
#          ...
# 17374    0.60
# 17375    0.60
# 17376    0.60
# 17377    0.56
# 17378    0.65
# Name: hum, Length: 17379, dtype: float64

# %%
cw['hum'].fillna(0)
# Out:
# 0        0.81
# 1        0.80
# 2        0.80
# 3        0.75
# 4        0.75
#          ...
# 17374    0.60
# 17375    0.60
# 17376    0.60
# 17377    0.56
# 17378    0.65
# Name: hum, Length: 17379, dtype: float64

# %%
cw['count']=cw['casual']+cw['registered']
cw
# Out:
#        instant      dteday  season  hr  weekday  weathersit  temp   atemp  \
# 0            1  2011-01-01     1.0   0   Monday           1  0.24  0.2879
# 1            2  2011-01-01     NaN   1   Monday           1  0.22  0.2727
# 2            3  2011-01-01     1.0   2   Monday           1  0.22  0.2727
# 3            4  2011-01-01     1.0   3   Monday           1  0.24  0.2879
# 4            5  2011-01-01     1.0   4   Monday           1  0.24  0.2879
# ...        ...         ...     ...  ..      ...         ...   ...     ...
# 17374    17375  2012-12-31     1.0  19  Tuesday           2  0.26  0.2576
# 17375    17376  2012-12-31     1.0  20  Tuesday           2  0.26  0.2576
# 17376    17377  2012-12-31     1.0  21  Tuesday           1  0.26  0.2576
# 17377    17378  2012-12-31     1.0  22  Tuesday           1  0.26  0.2727
# 17378    17379  2012-12-31     NaN  23  Tuesday           1  0.26  0.2727
#
#         hum  windspeed  casual  registered  count
# ...

# %%
del cw['casual'], cw['registered']

# %%
cw['dteday'] = pd.to_datetime(cw['dteday'])
holidays = ['2011-01-17', '2011-02-21', '2011-04-15', '2011-05-30', '2011-07-04', '2011-09-05', '2011-10-10', '2011-11-11', '2011-11-24', '2011-12-26', '2012-01-02', '2012-01-16', '2012-02-20', '2012-04-16', '2012-05-28', '2012-07-04', '2012-09-03', '2012-10-08', '2012-11-12', '2012-11-22', '2012-12-25']
cw['day_type'] = cw['dteday'].apply(lambda x: 'holiday' if x.strftime('%Y-%m-%d') in holidays else 'work day')
cw
# Out:
#        instant     dteday  season  hr  weekday  weathersit  temp   atemp  \
# 0            1 2011-01-01     1.0   0   Monday           1  0.24  0.2879
# 1            2 2011-01-01     NaN   1   Monday           1  0.22  0.2727
# 2            3 2011-01-01     1.0   2   Monday           1  0.22  0.2727
# 3            4 2011-01-01     1.0   3   Monday           1  0.24  0.2879
# 4            5 2011-01-01     1.0   4   Monday           1  0.24  0.2879
# ...        ...        ...     ...  ..      ...         ...   ...     ...
# 17374    17375 2012-12-31     1.0  19  Tuesday           2  0.26  0.2576
# 17375    17376 2012-12-31     1.0  20  Tuesday           2  0.26  0.2576
# 17376    17377 2012-12-31     1.0  21  Tuesday           1  0.26  0.2576
# 17377    17378 2012-12-31     1.0  22  Tuesday           1  0.26  0.2727
# 17378    17379 2012-12-31     NaN  23  Tuesday           1  0.26  0.2727
#
#         hum  windspeed  casual  registered  count  day_type
# ...

# %%
date = '2011-01-17'
filtered_row = cw.loc[cw['dteday'] == desired_date]
print(filtered_row)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dteday'
#
# The above exception was the direct cause of the following exception:
#
# ...
